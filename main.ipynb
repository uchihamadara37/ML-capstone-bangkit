# %% [markdown]
# <a href="https://colab.research.google.com/github/Az140304/MachineLearning/blob/main/main.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#import kagglehub
import os
from zipfile import ZipFile 
import pathlib

# %%
# !pip install kagglehub

# %%
# !pip install tensorflow

# %%
# !mkdir ~\.kaggle

# %%
os.chdir("~/.kaggle/")

# %%
# !kaggle datasets download wangziang/waste-pictures
# Out:
# Dataset URL: https://www.kaggle.com/datasets/wangziang/waste-pictures
# License(s): unknown
# ...
#   0%|          | 0.00/2.05G [00:00<?, ?B/s]
#   0%|          | 1.00M/2.05G [00:01<41:48, 877kB/s]
#   0%|          | 2.00M/2.05G [00:01<20:48, 1.76MB/s]
#   0%|          | 3.00M/2.05G [00:01<13:50, 2.64MB/s]
#   0%|          | 4.00M/2.05G [00:01<10:39, 3.43MB/s]
#   0%|          | 5.00M/2.05G [00:01<08:57, 4.08MB/s]
#   0%|          | 6.00M/2.05G [00:02<07:53, 4.64MB/s]
#   0%|          | 7.00M/2.05G [00:02<07:13, 5.06MB/s]
#   0%|          | 8.00M/2.05G [00:02<06:45, 5.40MB/s]
#   0%|          | 9.00M/2.05G [00:02<06:30, 5.61MB/s]
#   0%|          | 10.0M/2.05G [00:02<06:17, 5.80MB/s]
#   1%|          | 11.0M/2.05G [00:02<06:09, 5.93MB/s]
#   1%|          | 12.0M/2.05G [00:03<07:05, 5.14MB/s]
#   1%|          | 13.0M/2.05G [00:03<06:04, 6.00MB/s]
#   1%|          | 14.0M/2.05G [00:03<06:00, 6.06MB/s]
#   1%|          | 15.0M/2.05G [00:03<05:56, 6.12MB/s]
# ...

# %%
os.getcwd()
# Out:
# 'd:\\pythoncoding\\bangkit-project-ml\\MachineLearning\\~\\.kaggle'

# %%
# specifying the zip file name 
file_name = "waste-pictures.zip"

# %%
# opening the zip file in READ mode 
with ZipFile(file_name, 'r') as zip: 
    # printing all the contents of the zip file 
    zip.printdir() 
  
    # extracting all the files 
    print('Extracting all the files now...') 
    zip.extractall() 
    print('Done!')
# Out:
# File Name                                             Modified             Size
# test/XLight/XLight (1).jpg                     2019-10-21 09:15:32        26466
# test/XLight/XLight (1).png                     2019-10-21 09:15:34       399527
# test/XLight/XLight (10).jpg                    2019-10-21 09:15:34       363930
# test/XLight/XLight (10).png                    2019-10-21 09:15:34        66112
# test/XLight/XLight (100).jpg                   2019-10-21 09:15:34       186246
# test/XLight/XLight (101).jpg                   2019-10-21 09:15:34        13302
# test/XLight/XLight (102).jpg                   2019-10-21 09:15:34        12926
# test/XLight/XLight (103).jpg                   2019-10-21 09:15:34        24718
# test/XLight/XLight (104).jpg                   2019-10-21 09:15:36        34775
# test/XLight/XLight (105).jpg                   2019-10-21 09:15:36        32538
# test/XLight/XLight (106).jpg                   2019-10-21 09:15:36        79337
# ...

# %%
test_dir = "./test/"
train_dir = "./train/"

# %% [markdown]
# ### Check for faulty extension

# %%
# Get the list of all files and directories
def count_acceptable_ext(dir):
    positive_count = 0
    negative_count = 0
    image_extensions = {'.jpg', '.jpeg', '.png'}

    trash_type_list = os.listdir(dir)
    for trash_type in trash_type_list:
        trash_type_dir = os.path.join(dir, trash_type)
        for file_name in os.listdir(trash_type_dir):
            file_ext = pathlib.Path(file_name).suffix.lower()
            if file_ext in image_extensions:
                print(f"{file_name} is a {file_ext}, accepted by TensorFlow")
                positive_count+=1
            else:
                print(f"{file_name} is a {file_ext}, not accepted by TensorFlow")
                negative_count+=1

    print("acceptable : {}, not acceptable : {}".format(positive_count, negative_count))

count_acceptable_ext(train_dir)
print("asdad")
# Out:
# bandaid (1).jpeg is a .jpeg, accepted by TensorFlow
# bandaid (1).jpg is a .jpg, accepted by TensorFlow
# bandaid (1).png is a .png, accepted by TensorFlow
# bandaid (10).jpeg is a .jpeg, accepted by TensorFlow
# bandaid (10).jpg is a .jpg, accepted by TensorFlow
# bandaid (100).jpg is a .jpg, accepted by TensorFlow
# bandaid (101).jpg is a .jpg, accepted by TensorFlow
# bandaid (102).jpg is a .jpg, accepted by TensorFlow
# bandaid (103).jpg is a .jpg, accepted by TensorFlow
# bandaid (104).jpg is a .jpg, accepted by TensorFlow
# bandaid (105).jpg is a .jpg, accepted by TensorFlow
# bandaid (106).jpg is a .jpg, accepted by TensorFlow
# bandaid (107).jpg is a .jpg, accepted by TensorFlow
# bandaid (108).jpg is a .jpg, accepted by TensorFlow
# bandaid (109).jpg is a .jpg, accepted by TensorFlow
# bandaid (11).jpeg is a .jpeg, accepted by TensorFlow
# bandaid (11).jpg is a .jpg, accepted by TensorFlow
# bandaid (110).jpg is a .jpg, accepted by TensorFlow
# ...
